# %%
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime
import  matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("timeSeries19CovidCombined.csv")

# %%
data.head(10)
# Out:
#          Date Country/Region Province/State       Lat       Long  Confirmed  \
# 0  2020-01-22    Afghanistan            NaN  33.93911  67.709953          0
# 1  2020-01-23    Afghanistan            NaN  33.93911  67.709953          0
# 2  2020-01-24    Afghanistan            NaN  33.93911  67.709953          0
# 3  2020-01-25    Afghanistan            NaN  33.93911  67.709953          0
# 4  2020-01-26    Afghanistan            NaN  33.93911  67.709953          0
# 5  2020-01-27    Afghanistan            NaN  33.93911  67.709953          0
# 6  2020-01-28    Afghanistan            NaN  33.93911  67.709953          0
# 7  2020-01-29    Afghanistan            NaN  33.93911  67.709953          0
# 8  2020-01-30    Afghanistan            NaN  33.93911  67.709953          0
# 9  2020-01-31    Afghanistan            NaN  33.93911  67.709953          0
#
#    Recovered  Deaths
# 0        0.0       0
# 1        0.0       0
# 2        0.0       0
# 3        0.0       0
# ...

# %%
data.tail(10)
# Out:
#              Date Country/Region Province/State        Lat       Long  \
# 72080  2020-10-08       Zimbabwe            NaN -19.015438  29.154857
# 72081  2020-10-09       Zimbabwe            NaN -19.015438  29.154857
# 72082  2020-10-10       Zimbabwe            NaN -19.015438  29.154857
# 72083  2020-10-11       Zimbabwe            NaN -19.015438  29.154857
# 72084  2020-10-12       Zimbabwe            NaN -19.015438  29.154857
# 72085  2020-10-13       Zimbabwe            NaN -19.015438  29.154857
# 72086  2020-10-14       Zimbabwe            NaN -19.015438  29.154857
# 72087  2020-10-15       Zimbabwe            NaN -19.015438  29.154857
# 72088  2020-10-16       Zimbabwe            NaN -19.015438  29.154857
# 72089  2020-10-17       Zimbabwe            NaN -19.015438  29.154857
#
#        Confirmed  Recovered  Deaths
# 72080       7951     6446.0     229
# 72081       7994     6474.0     229
# 72082       8010     6492.0     230
# 72083       8011     6504.0     230
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72090 entries, 0 to 72089
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            72090 non-null  object
#  1   Country/Region  72090 non-null  object
#  2   Province/State  21870 non-null  object
#  3   Lat             72090 non-null  float64
#  4   Long            72090 non-null  float64
#  5   Confirmed       72090 non-null  int64
#  6   Recovered       68310 non-null  float64
#  7   Deaths          72090 non-null  int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 4.4+ MB

# %%
data.describe()
# Out:
#                 Lat          Long     Confirmed     Recovered         Deaths
# count  72090.000000  72090.000000  7.209000e+04  6.831000e+04   72090.000000
# mean      20.961559     23.343773  4.284619e+04  2.760750e+04    1610.020807
# std       24.882193     70.429778  3.257632e+05  2.119790e+05   10272.269230
# min      -51.796300   -135.000000  0.000000e+00  0.000000e+00       0.000000
# 25%        6.428055    -15.310100  1.600000e+01  3.000000e+00       0.000000
# 50%       22.300000     20.939400  4.400000e+02  2.020000e+02       6.000000
# 75%       41.153300     80.771797  4.688750e+03  2.150000e+03      89.000000
# max       71.706900    178.065000  8.106384e+06  6.524595e+06  219286.000000

# %%
data.shape
# Out:
# (72090, 8)

# %%
data.dtypes
# Out:
# Date               object
# Country/Region     object
# Province/State     object
# Lat               float64
# Long              float64
# Confirmed           int64
# Recovered         float64
# Deaths              int64
# dtype: object

# %%
data.isna().sum()
# Out:
# Date                  0
# Country/Region        0
# Province/State    50220
# Lat                   0
# Long                  0
# Confirmed             0
# Recovered          3780
# Deaths                0
# dtype: int64

# %%
data["Province/State"] = data["Province/State"].fillna("No State")

# %%
data.isnull().sum()
# Out:
# Date                 0
# Country/Region       0
# Province/State       0
# Lat                  0
# Long                 0
# Confirmed            0
# Recovered         3780
# Deaths               0
# dtype: int64

# %%
data.head()
# Out:
#          Date Country/Region Province/State       Lat       Long  Confirmed  \
# 0  2020-01-22    Afghanistan       No State  33.93911  67.709953          0
# 1  2020-01-23    Afghanistan       No State  33.93911  67.709953          0
# 2  2020-01-24    Afghanistan       No State  33.93911  67.709953          0
# 3  2020-01-25    Afghanistan       No State  33.93911  67.709953          0
# 4  2020-01-26    Afghanistan       No State  33.93911  67.709953          0
#
#    Recovered  Deaths
# 0        0.0       0
# 1        0.0       0
# 2        0.0       0
# 3        0.0       0
# 4        0.0       0

# %%
data = data.set_index('Date')
data.head(3)
# Out:
#            Country/Region Province/State       Lat       Long  Confirmed  \
# Date
# 2020-01-22    Afghanistan       No State  33.93911  67.709953          0
# 2020-01-23    Afghanistan       No State  33.93911  67.709953          0
# 2020-01-24    Afghanistan       No State  33.93911  67.709953          0
#
#             Recovered  Deaths
# Date
# 2020-01-22        0.0       0
# 2020-01-23        0.0       0
# 2020-01-24        0.0       0

# %%
data.index
# Out:
# Index(['2020-01-22', '2020-01-23', '2020-01-24', '2020-01-25', '2020-01-26',
#        '2020-01-27', '2020-01-28', '2020-01-29', '2020-01-30', '2020-01-31',
#        ...
#        '2020-10-08', '2020-10-09', '2020-10-10', '2020-10-11', '2020-10-12',
#        '2020-10-13', '2020-10-14', '2020-10-15', '2020-10-16', '2020-10-17'],
#       dtype='object', name='Date', length=72090)

# %%
data = pd.read_csv('timeSeries19CovidCombined.csv', index_col=0, parse_dates=True)

# %%
# Add columns with year, month, and weekday name
data['Year'] = data.index.year
data['Month'] = data.index.month
data['Day'] = data.index.weekday

# %%
# Display a random sampling of 5 rows
data.sample(5, random_state=0)
# Out:
#            Country/Region Province/State        Lat        Long  Confirmed  \
# Date
# 2020-03-26      Australia     Queensland -27.469800  153.025100        493
# 2020-06-13    Switzerland            NaN  46.818200    8.227500      31094
# 2020-03-29        Bahamas            NaN  25.025885  -78.035889         11
# 2020-09-29          Burma            NaN  21.916200   95.956000      12425
# 2020-02-15          China      Hong Kong  22.300000  114.200000         56
#
#             Recovered  Deaths  Year  Month  Day
# Date
# 2020-03-26        8.0       1  2020      3    3
# 2020-06-13    28800.0    1938  2020      6    5
# 2020-03-29        1.0       0  2020      3    6
# 2020-09-29     3391.0     284  2020      9    1
# 2020-02-15        1.0       1  2020      2    5

# %% [markdown]
# ### Time-based indexing

# %%
data.loc['2020-03-26']
# Out:
#                 Country/Region Province/State        Lat       Long  \
# Date
# 2020-03-26         Afghanistan            NaN  33.939110  67.709953
# 2020-03-26             Albania            NaN  41.153300  20.168300
# 2020-03-26             Algeria            NaN  28.033900   1.659600
# 2020-03-26             Andorra            NaN  42.506300   1.521800
# 2020-03-26              Angola            NaN -11.202700  17.873900
# ...                        ...            ...        ...        ...
# 2020-03-26  West Bank and Gaza            NaN  31.952200  35.233200
# 2020-03-26      Western Sahara            NaN  24.215500 -12.885800
# 2020-03-26               Yemen            NaN  15.552727  48.516388
# 2020-03-26              Zambia            NaN -13.133897  27.849332
# 2020-03-26            Zimbabwe            NaN -19.015438  29.154857
#
#             Confirmed  Recovered  Deaths  Year  Month  Day
# Date
# 2020-03-26         94        2.0       4  2020      3    3
# ...

# %%
data.loc['2020-03-26' : '2020-03-29']
# Out:
#            Country/Region Province/State        Lat       Long  Confirmed  \
# Date
# 2020-03-26    Afghanistan            NaN  33.939110  67.709953         94
# 2020-03-27    Afghanistan            NaN  33.939110  67.709953        110
# 2020-03-28    Afghanistan            NaN  33.939110  67.709953        110
# 2020-03-29    Afghanistan            NaN  33.939110  67.709953        120
# 2020-03-26        Albania            NaN  41.153300  20.168300        174
# ...                   ...            ...        ...        ...        ...
# 2020-03-29         Zambia            NaN -13.133897  27.849332         29
# 2020-03-26       Zimbabwe            NaN -19.015438  29.154857          3
# 2020-03-27       Zimbabwe            NaN -19.015438  29.154857          5
# 2020-03-28       Zimbabwe            NaN -19.015438  29.154857          7
# 2020-03-29       Zimbabwe            NaN -19.015438  29.154857          7
#
#             Recovered  Deaths  Year  Month  Day
# Date
# ...

# %% [markdown]
# ### Visualizing time series data

# %%
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})

# %%
data['Confirmed'].plot(linewidth=0.5);

# %%
data['Recovered'].plot(linewidth=0.5);

# %%
data['Deaths'].plot(linewidth=0.5);
